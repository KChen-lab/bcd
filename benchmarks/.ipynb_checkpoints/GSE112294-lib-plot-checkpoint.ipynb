# %%
import scanpy as sc
import scipy as sp
import pandas as pd

# %%
import scib_metrics
from scib_metrics.benchmark import Benchmarker

# %%
adata = sc.read_h5ad("../data/GSE112294/WagnerScience2018.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 63530 × 30677
#     obs: 'n_counts', 'unique_cell_id', 'cell_names', 'library_id', 'batch', 'ClusterID', 'ClusterName', 'TissueID', 'TissueName', 'TimeID'

# %%
# sp.io.mmwrite("../data/GSE112294/WagnerScience2018.mtx", adata.X)
# adata.var.to_csv("../data/GSE112294/WagnerScience2018_genes.csv")
# adata.obs.to_csv("../data/GSE112294/WagnerScience2018_metadata.csv")

# %%
adata.obs['celltype'] = adata.obs['ClusterName'].str[6:]

# %%
pd.crosstab(adata.obs['TissueName'], adata.obs['celltype'])
# Out:
# celltype                     EVL  anterior neural ridge  apoptotic-like  \
# TissueName
# Endoderm                  0    0                      0               0
# Epidermal                 0   53                    209               0
# Forebrain / Optic         0    0                      0               0
# Germline                  0    0                      0               0
# Hindbrain / Spinal Cord   0    0                      0               0
# Mesoderm                  0    0                      0               0
# Midbrain                  0    0                      0               0
# NaN                      58    0                      0               0
# Neural Crest              0    0                      0               0
# Other                     0    0                      0             163
# Pluripotent               0    0                      0               0
#
# celltype                 apoptotic-like 2  differentiating neurons  \
# TissueName
# Endoderm                                0                        0
# Epidermal                               0                        0
# Forebrain / Optic                       0                        0
# Germline                                0                        0
# Hindbrain / Spinal Cord                 0                     3262
# Mesoderm                                0                        0
# Midbrain                                0                        0
# NaN                                     0                        0
# Neural Crest                            0                        0
# Other                                  33                        0
# Pluripotent                             0                        0
#
# celltype                 differentiating neurons - dlx  \
# TissueName
# Endoderm                                             0
# Epidermal                                            0
# Forebrain / Optic                                  424
# Germline                                             0
# Hindbrain / Spinal Cord                              0
# Mesoderm                                             0
# Midbrain                                             0
# NaN                                                  0
# Neural Crest                                         0
# Other                                                0
# Pluripotent                                          0
#
# celltype                 differentiating neurons - eomesa  \
# TissueName
# Endoderm                                                0
# Epidermal                                               0
# Forebrain / Optic                                     423
# Germline                                                0
# Hindbrain / Spinal Cord                                 0
# Mesoderm                                                0
# Midbrain                                                0
# NaN                                                     0
# Neural Crest                                            0
# Other                                                   0
# Pluripotent                                             0
#
# celltype                 differentiating neurons - hmx  \
# TissueName
# Endoderm                                             0
# Epidermal                                            0
# Forebrain / Optic                                   83
# Germline                                             0
# Hindbrain / Spinal Cord                              0
# Mesoderm                                             0
# Midbrain                                             0
# NaN                                                  0
# Neural Crest                                         0
# Other                                                0
# Pluripotent                                          0
#
# celltype                 differentiating neurons - phox2a  ...  \
# TissueName                                                 ...
# Endoderm                                                0  ...
# Epidermal                                               0  ...
# Forebrain / Optic                                       0  ...
# Germline                                                0  ...
# Hindbrain / Spinal Cord                               205  ...
# Mesoderm                                                0  ...
# Midbrain                                                0  ...
# NaN                                                     0  ...
# Neural Crest                                            0  ...
# Other                                                   0  ...
# Pluripotent                                             0  ...
#
# celltype                 pharyngeal pouch  pluripotent  prechordal plate  \
# TissueName
# Endoderm                              209            0                 0
# Epidermal                               0            0                 0
# Forebrain / Optic                       0            0                 0
# Germline                                0            0                 0
# Hindbrain / Spinal Cord                 0            0                 0
# Mesoderm                                0            0                79
# Midbrain                                0            0                 0
# NaN                                     0            0                 0
# Neural Crest                            0            0                 0
# Other                                   0            0                 0
# Pluripotent                             0         4277                 0
#
# celltype                 prechordal plate - hatching gland  proctodeum  \
# TissueName
# Endoderm                                                 0           0
# Epidermal                                                0           0
# Forebrain / Optic                                        0           0
# Germline                                                 0           0
# Hindbrain / Spinal Cord                                  0           0
# Mesoderm                                                45          32
# Midbrain                                                 0           0
# NaN                                                      0           0
# Neural Crest                                             0           0
# Other                                                    0           0
# Pluripotent                                              0           0
#
# celltype                 pronephric duct  pronephric duct - posterior  \
# TissueName
# Endoderm                               0                            0
# Epidermal                              0                            0
# Forebrain / Optic                      0                            0
# Germline                               0                            0
# Hindbrain / Spinal Cord                0                            0
# Mesoderm                              38                           11
# Midbrain                               0                            0
# NaN                                    0                            0
# Neural Crest                           0                            0
# Other                                  0                            0
# Pluripotent                            0                            0
#
# celltype                 retina pigmented epithelium  tailbud - PSM  \
# TissueName
# Endoderm                                           0              0
# Epidermal                                          0              0
# Forebrain / Optic                                198              0
# Germline                                           0              0
# Hindbrain / Spinal Cord                            0              0
# Mesoderm                                           0           1526
# Midbrain                                           0              0
# NaN                                                0              0
# Neural Crest                                       0              0
# Other                                              0              0
# Pluripotent                                        0              0
#
# celltype                 tailbud - spinal cord
# TissueName
# Endoderm                                     0
# Epidermal                                    0
# Forebrain / Optic                            0
# Germline                                     0
# Hindbrain / Spinal Cord                   3759
# Mesoderm                                     0
# Midbrain                                     0
# NaN                                          0
# Neural Crest                                 0
# Other                                        0
# Pluripotent                                  0
#
# [11 rows x 124 columns]

# %%
methods = ['pca', 'seurat', 'seurat_rpca', 'harmony', 'limma', 'bcd']
sample = 'gse112294_lib'

metadata = pd.read_csv(f"../output-embeddings/gse112294_label.csv", index_col=0)

# %%
embs = {}
for m in methods:
    embs[m] = pd.read_csv(f"../output-embeddings/{sample}_{m}.csv", index_col=0)
    if m in ['pca', 'limma']:
        embs[m] = embs[m].iloc[:, :30]
    print(m, embs[m].shape)
# Out:
# pca (63530, 30)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 embs = {}
#       2 for m in methods:
# ----> 3     embs[m] = pd.read_csv(f"../output-embeddings/{sample}_{m}.csv", index_col=0)
#       4     if m in ['pca', 'limma']:
#       5         embs[m] = embs[m].iloc[:, :30]
#
# File ~\miniconda3\envs\py39_integration\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\miniconda3\envs\py39_integration\lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\miniconda3\envs\py39_integration\lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\miniconda3\envs\py39_integration\lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\miniconda3\envs\py39_integration\lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../output-embeddings/gse112294_lib_seurat.csv'

# %%
label = 'celltype'
batch = "TimeID"
use_cosine = []

# %%
for m in methods:
    matrix_name = m
    adata.obsm[matrix_name] = embs[m].to_numpy()

# %%
from scib_metrics.benchmark import BioConservation, BatchCorrection
bm = Benchmarker(
    adata,
    batch_key=batch,
    label_key=label,
    embedding_obsm_keys=methods,
    bio_conservation_metrics=BioConservation(isolated_labels=True, nmi_ari_cluster_labels_leiden=False, nmi_ari_cluster_labels_kmeans=False, silhouette_label=True, clisi_knn=False),
    batch_correction_metrics=BatchCorrection(silhouette_batch=True, ilisi_knn=False, kbet_per_label=False, graph_connectivity=True, pcr_comparison=False),
    n_jobs=6,
)
bm.benchmark()
# Out:
# Computing neighbors: 100%|███████████████████████████████████████████████████████████████| 5/5 [03:24<00:00, 40.98s/it]
# Embeddings:   0%|                                                                                | 0/5 [00:00<?, ?it/s]
# Metrics:   0%|                                                                                  | 0/10 [00:00<?, ?it/s]
# Metrics:   0%|                                               | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|███▉                                   | 1/10 [00:15<02:20, 15.59s/it, Bio conservation: isolated_labels]
# Metrics:  10%|███▊                                  | 1/10 [00:15<02:20, 15.59s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [00:31<02:06, 15.83s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [00:31<02:06, 15.83s/it, Batch correction: silhouette_batch]
# Metrics:  30%|███████████▍                          | 3/10 [00:53<02:09, 18.53s/it, Batch correction: silhouette_batch]
# Metrics:  30%|██████████▊                         | 3/10 [00:53<02:09, 18.53s/it, Batch correction: graph_connectivity]C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scib_metrics\_graph_connectivity.py:27: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  20%|██████████████▍                                                         | 1/5 [00:53<03:35, 53.78s/it]
# Metrics:   0%|                                                                                  | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|                                               | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|███▉                                   | 1/10 [00:14<02:10, 14.52s/it, Bio conservation: isolated_labels]
# Metrics:  10%|███▊                                  | 1/10 [00:14<02:10, 14.52s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [00:28<01:54, 14.35s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [00:28<01:54, 14.35s/it, Batch correction: silhouette_batch]
# Metrics:  30%|███████████▍                          | 3/10 [00:29<00:57,  8.24s/it, Batch correction: silhouette_batch]
# Metrics:  30%|██████████▊                         | 3/10 [00:29<00:57,  8.24s/it, Batch correction: graph_connectivity]C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scib_metrics\_graph_connectivity.py:27: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  40%|████████████████████████████▊                                           | 2/5 [01:23<01:59, 39.88s/it]
# Metrics:   0%|                                                                                  | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|                                               | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|███▉                                   | 1/10 [00:16<02:26, 16.27s/it, Bio conservation: isolated_labels]
# Metrics:  10%|███▊                                  | 1/10 [00:16<02:26, 16.27s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [00:30<02:01, 15.23s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [00:30<02:01, 15.23s/it, Batch correction: silhouette_batch]
# Metrics:  30%|███████████▍                          | 3/10 [00:31<01:01,  8.72s/it, Batch correction: silhouette_batch]
# Metrics:  30%|██████████▊                         | 3/10 [00:31<01:01,  8.72s/it, Batch correction: graph_connectivity]C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scib_metrics\_graph_connectivity.py:27: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  60%|███████████████████████████████████████████▏                            | 3/5 [01:56<01:12, 36.37s/it]
# Metrics:   0%|                                                                                  | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|                                               | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|███▉                                   | 1/10 [00:15<02:15, 15.02s/it, Bio conservation: isolated_labels]
# Metrics:  10%|███▊                                  | 1/10 [00:15<02:15, 15.02s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [00:29<01:56, 14.59s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [00:29<01:56, 14.59s/it, Batch correction: silhouette_batch]
# Metrics:  30%|███████████▍                          | 3/10 [00:30<00:58,  8.37s/it, Batch correction: silhouette_batch]
# Metrics:  30%|██████████▊                         | 3/10 [00:30<00:58,  8.37s/it, Batch correction: graph_connectivity]C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scib_metrics\_graph_connectivity.py:27: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  80%|█████████████████████████████████████████████████████████▌              | 4/5 [02:26<00:34, 34.14s/it]
# Metrics:   0%|                                                                                  | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|                                               | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|███▉                                   | 1/10 [00:14<02:10, 14.49s/it, Bio conservation: isolated_labels]
# Metrics:  10%|███▊                                  | 1/10 [00:14<02:10, 14.49s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [00:28<01:55, 14.44s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [00:28<01:55, 14.44s/it, Batch correction: silhouette_batch]
# Metrics:  30%|███████████▍                          | 3/10 [00:29<00:58,  8.29s/it, Batch correction: silhouette_batch]
# Metrics:  30%|██████████▊                         | 3/10 [00:29<00:58,  8.29s/it, Batch correction: graph_connectivity]C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scib_metrics\_graph_connectivity.py:27: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
# Embeddings: 100%|████████████████████████████████████████████████████████████████████████| 5/5 [02:57<00:00, 35.43s/it]

# %%
bm.plot_results_table(min_max_scale=False)
