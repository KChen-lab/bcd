# %%
import scanpy as sc
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import scib_metrics
from scib_metrics.benchmark import Benchmarker

# %%
methods = ['bcd_umap', 'pca_umap', 'limma_umap', 'seurat_umap', 'seurat_rpca_umap', 'harmony_umap']
sample = 'gse145926'

metadata = pd.read_csv(f"../output-embeddings/gse145926_label.csv", index_col=0)

# %%
embs = {}
for m in methods:
    embs[m] = pd.read_csv(f"../output-embeddings/{sample}_{m}.csv", index_col=0)

# %%
adata = sc.AnnData(np.zeros([len(metadata), 0]), obs=metadata)
adata
# Out:
# AnnData object with n_obs × n_vars = 65813 × 0
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'ID', 'sample', 'sample_new', 'group', 'disease', 'hasnCoV', 'cluster', 'celltype', 'RNA_snn_res.0.5', 'seurat_clusters', 'pca_clusters', 'alt_clusters'

# %%
for m in methods:
    matrix_name = m
    adata.obsm[matrix_name] = embs[m].to_numpy()

# %%
adata.obs
# Out:
#                     orig.ident  nCount_RNA  nFeature_RNA                   ID  \
# AAACCTGAGACACTAA_1         HC1        5228          1635   AAACCTGAGACACTAA_1
# AAACCTGAGGAGTACC_1         HC1        5072          1386   AAACCTGAGGAGTACC_1
# AAACCTGAGGATATAC_1         HC1        5531          1729   AAACCTGAGGATATAC_1
# AAACCTGAGGTCATCT_1         HC1        5630          1639   AAACCTGAGGTCATCT_1
# AAACCTGCACGGATAG_1         HC1        7358          1722   AAACCTGCACGGATAG_1
# ...                        ...         ...           ...                  ...
# TTTGGTTTCGCTTGTC_13         S6        1116           641  TTTGGTTTCGCTTGTC_13
# TTTGTCAAGAAACGCC_13         S6       12872          3510  TTTGTCAAGAAACGCC_13
# TTTGTCACAACACCCG_13         S6        1347           556  TTTGTCACAACACCCG_13
# TTTGTCAGTCTGCAAT_13         S6       21275          3374  TTTGTCAGTCTGCAAT_13
# TTTGTCAGTGTTGGGA_13         S6        4301          1705  TTTGTCAGTGTTGGGA_13
#
#                     sample sample_new group disease hasnCoV  cluster  \
# AAACCTGAGACACTAA_1     C51        HC1    HC       N       N        3
# AAACCTGAGGAGTACC_1     C51        HC1    HC       N       N        3
# AAACCTGAGGATATAC_1     C51        HC1    HC       N       N        3
# AAACCTGAGGTCATCT_1     C51        HC1    HC       N       N        3
# AAACCTGCACGGATAG_1     C51        HC1    HC       N       N        5
# ...                    ...        ...   ...     ...     ...      ...
# TTTGGTTTCGCTTGTC_13   C152         S6     S       Y       N        1
# TTTGTCAAGAAACGCC_13   C152         S6     S       Y       N       14
# TTTGTCACAACACCCG_13   C152         S6     S       Y       N       19
# TTTGTCAGTCTGCAAT_13   C152         S6     S       Y       N       19
# TTTGTCAGTGTTGGGA_13   C152         S6     S       Y       N       10
#
#                         celltype  RNA_snn_res.0.5  seurat_clusters  \
# AAACCTGAGACACTAA_1   Macrophages                3                3
# AAACCTGAGGAGTACC_1   Macrophages                3                3
# AAACCTGAGGATATAC_1   Macrophages                3                3
# AAACCTGAGGTCATCT_1   Macrophages                3                3
# AAACCTGCACGGATAG_1   Macrophages                2                2
# ...                          ...              ...              ...
# TTTGGTTTCGCTTGTC_13  Macrophages                0                0
# TTTGTCAAGAAACGCC_13            T                9                9
# TTTGTCACAACACCCG_13       Plasma               13               13
# TTTGTCAGTCTGCAAT_13       Plasma               13               13
# TTTGTCAGTGTTGGGA_13  Macrophages                6                6
#
#                      pca_clusters  alt_clusters
# AAACCTGAGACACTAA_1              2             3
# AAACCTGAGGAGTACC_1              2             3
# AAACCTGAGGATATAC_1              2             3
# AAACCTGAGGTCATCT_1              2             3
# AAACCTGCACGGATAG_1              3             2
# ...                           ...           ...
# TTTGGTTTCGCTTGTC_13             0             0
# TTTGTCAAGAAACGCC_13            10             9
# TTTGTCACAACACCCG_13            12            13
# TTTGTCAGTCTGCAAT_13            12            13
# TTTGTCAGTGTTGGGA_13             5             6
#
# [65813 rows x 15 columns]

# %%
fig, axes = plt.subplots(4, 4, figsize=(9, 8))
for i, m in enumerate(methods):
    legend_loc = None
    if i == 3:
        legend_loc = 'right margin'
    sc.pl.embedding(adata, m, color='sample_new', ax=axes[(i // 4) * 2][i % 4], legend_loc=legend_loc, title='', legend_fontsize=10, 
                    alpha=0.5, size=0.5)
    sc.pl.embedding(adata, m, color='celltype', ax=axes[(i // 4) * 2 + 1][i % 4], legend_loc=legend_loc, title='', legend_fontsize=10, 
                    alpha=0.5, size=0.5)
    if i == 3:
        axes[(i // 4) * 2][i % 4].legend(ncol=2, bbox_to_anchor=(1., 1.), frameon=False, fontsize=10)
        axes[(i // 4) * 2 + 1][i % 4].legend(ncol=2, bbox_to_anchor=(1., 1.), frameon=False, fontsize=10)
        
for i in range(i + 1, 8):
    axes[(i // 4) * 2][i % 4].set_axis_off()
    axes[(i // 4) * 2 + 1][i % 4].set_axis_off()
plt.tight_layout(pad=1.5)
fig
# Out:
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
