# %% [markdown]
# ## Methods to compare in integration tasks
#
# Harmony and Liger are widely-used data integration / batch effect correction methods that have Python implementations. Harmony is usually considered to be less aggressive in strength, thus keeping more biological variance. Liger is suitable in situations with more severe batch effect.

# %%
import scanpy as sc
import sklearn as skl
import pandas as pd
import matplotlib.pyplot as plt
import pickle as pkl
import numpy as np

# %%
import scib_metrics
from scib_metrics.benchmark import Benchmarker

# %%
from tqdm import tqdm

# %%
import matplotlib as mpl

# %% [markdown]
# ## Load data and view the data without integration

# %%
methods = ['pca', 'seurat', 'seurat_rpca', 'harmony', 'limma', 'bcd']
sample = 'gse118614'

metadata = pd.read_csv(f"../output-embeddings/{sample}_label.csv", index_col=0)

# %%
embs = {}
for m in methods:
    embs[m] = pd.read_csv(f"../output-embeddings/{sample}_{m}.csv", index_col=0)
    if m in ['pca', 'limma']:
        embs[m] = embs[m].iloc[:, :30]
    print(m, embs[m].shape)
# Out:
# pca (110359, 30)
# seurat (110359, 30)
# seurat_rpca (110359, 30)
# harmony (110359, 30)
# limma (110359, 30)
# bcd (110359, 10)

# %%
metadata
# Out:
#                            orig.ident  nCount_RNA  nFeature_RNA  age   sample  \
# E11.AAACCTGAGATGTAAC-1         retina        2794          1549  E11      E11
# E11.AAACCTGAGGCAATTA-1         retina        3548          1848  E11      E11
# E11.AAACCTGAGTAGCGGT-1         retina        3838          1935  E11      E11
# E11.AAACCTGAGTGGAGTC-1         retina        4612          2139  E11      E11
# E11.AAACCTGCAAGTTGTC-1         retina        3296          1723  E11      E11
# ...                               ...         ...           ...  ...      ...
# P8_rep2.TTTGTCACAACCGCCA-1     retina         525           406   P8  P8_rep2
# P8_rep2.TTTGTCACAGGATTGG-1     retina         553           440   P8  P8_rep2
# P8_rep2.TTTGTCAGTCGGCTCA-1     retina         721           550   P8  P8_rep2
# P8_rep2.TTTGTCATCGCTTAGA-1     retina         748           579   P8  P8_rep2
# P8_rep2.TTTGTCATCTTAGCCC-1     retina         702           508   P8  P8_rep2
#
#                                  celltype short_celltype  RNA_snn_res.0.5  \
# E11.AAACCTGAGATGTAAC-1         Early RPCs           ERPC                1
# E11.AAACCTGAGGCAATTA-1         Early RPCs           ERPC                1
# E11.AAACCTGAGTAGCGGT-1         Early RPCs           ERPC                1
# E11.AAACCTGAGTGGAGTC-1         Early RPCs           ERPC                1
# E11.AAACCTGCAAGTTGTC-1         Early RPCs           ERPC               20
# ...                                   ...            ...              ...
# P8_rep2.TTTGTCACAACCGCCA-1  Bipolar Cells             BC               14
# P8_rep2.TTTGTCACAGGATTGG-1           Rods            Rod                4
# P8_rep2.TTTGTCAGTCGGCTCA-1  Bipolar Cells             BC               14
# P8_rep2.TTTGTCATCGCTTAGA-1  Bipolar Cells             BC               14
# P8_rep2.TTTGTCATCTTAGCCC-1           Rods            Rod                4
#
#                             seurat_clusters
# E11.AAACCTGAGATGTAAC-1                    1
# E11.AAACCTGAGGCAATTA-1                    1
# E11.AAACCTGAGTAGCGGT-1                    1
# E11.AAACCTGAGTGGAGTC-1                    1
# E11.AAACCTGCAAGTTGTC-1                   20
# ...                                     ...
# P8_rep2.TTTGTCACAACCGCCA-1               14
# P8_rep2.TTTGTCACAGGATTGG-1                4
# P8_rep2.TTTGTCAGTCGGCTCA-1               14
# P8_rep2.TTTGTCATCGCTTAGA-1               14
# P8_rep2.TTTGTCATCTTAGCCC-1                4
#
# [110359 rows x 9 columns]

# %%
uniform_dim = 10

# %% [markdown]
# ## Scoring and plotting

# %%
label = 'short_celltype'
batch = "sample"
use_cosine = []

# %%
ct = pd.crosstab(metadata[label], metadata[batch])
ct
# Out:
# sample           E11  E12_rep1  E14_rep1  E14_rep2   E16  E18_rep2  E18_rep3  \
# short_celltype
# Am                 0         1         1        56    13      1798      1997
# BC                 0         1         0         0     0         0         0
# Cone               0         0        16       158    38       631       681
# ERPC            8562      1517      9848      5595  2761       125       120
# HC                 0         0       401       564   380        70        92
# LRPC               0         0        44       541    84      5723      5506
# MG                 0         0         1         0     3         1         0
# Ng                 1        25      1562      1252   526      1120      1249
# Ph                 0         1        57       197   112       738       627
# RGC                0         8      2817      1831   996       200       317
# Rod                0         0         4         8    10        83       129
#
# sample            P0   P14  P2_rep2  P2_rep3    P5  P8_rep1  P8_rep2
# short_celltype
# Am              1444    11      767      918   629       20        7
# BC                 0  1610        0        0    65      955     1102
# Cone             403   476      180      294   317      170      277
# ERPC             129    34        9       21    28        3        0
# HC                70     3       28       21    31        0        0
# LRPC            5001     0     3433     4136   666        3        7
# MG                 5  1414       27       37  1123       29       21
# Ng              1194     0      954     1244   226        5       10
# Ph               693     0     1379     1827   852       49       23
# RGC               42     4        4        6    12        0        0
# Rod              174  4364      355      397  1581     6496     1345

# %%
scores = {}

for m in tqdm(methods):
    matrix_name = 'X_' + m
    
    adata = sc.AnnData(np.zeros([embs[m].shape[0], 0]), obs=metadata)
    adata.obsm[matrix_name] = embs[m]
    
    s = scib_metrics.silhouette_label(adata.obsm[matrix_name].to_numpy(), metadata[label])
    db = 0# skl.metrics.davies_bouldin_score(embs[m], metadata[label])
    ch = 0#skl.metrics.calinski_harabasz_score(embs[m], metadata[label])
    ilasw = scib_metrics.isolated_labels(adata.obsm[matrix_name].to_numpy(), metadata[label], metadata[batch])
    sb = scib_metrics.silhouette_batch(adata.obsm[matrix_name].to_numpy(), metadata[label], metadata[batch])
    
    scores[m] = [s, db, ch, ilasw, sb]
    
    # matrix_name = 'X_' + method
    
    # if method in use_cosine:
    #     sc.pp.neighbors(adata, use_rep=matrix_name, metric='cosine')
    # else:
    #     sc.pp.neighbors(adata, use_rep=matrix_name)
    
    # ilasw = scib.me.isolated_labels_asw(adata, batch_key=batch, label_key=label, embed=matrix_name)
    # ilf1 = scib.me.isolated_labels_f1(adata, batch_key=batch, label_key="cell_type", embed=None)
    # clisi = scib.me.clisi_graph(adata, label_key=label, type_="knn")
    
    # scores[m] = [s, db, ch, ilasw, ilf1, clisi]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [14:37<00:00, 146.24s/it]

# %%
scores = pd.DataFrame(scores, index=['silhouette', 'davies_bouldin', 'calinski_harabasz', 'silhouette_celltype', 'silhouette_batch']).T
# scores = pd.DataFrame(scores, index=['silhouette_celltype', 'silhouette_batch']).T
scores
# Out:
#              silhouette  davies_bouldin  calinski_harabasz  \
# pca            0.584303             0.0                0.0
# seurat         0.502741             0.0                0.0
# seurat_rpca    0.496623             0.0                0.0
# harmony        0.489526             0.0                0.0
# limma          0.542227             0.0                0.0
# bcd            0.584000             0.0                0.0
#
#              silhouette_celltype  silhouette_batch
# pca                     0.568620          0.873820
# seurat                  0.588937          0.853950
# seurat_rpca             0.602890          0.833366
# harmony                 0.475803          0.906259
# limma                   0.548378          0.901938
# bcd                     0.638703          0.848420

# %%
benchmarks = ['silhouette', 'silhouette_celltype', 'silhouette_batch']
lower_is_better = []
plt.subplots(1, len(benchmarks), figsize=(3.5, 3.5))
for i, v in enumerate(benchmarks):
    ax = plt.subplot(1, len(benchmarks), i + 1)
    
    color = mpl.colormaps['Blues'](1 - scores[v].rank(ascending=v in lower_is_better, pct=True) * .66)
    scores[v].plot(kind='bar', color=color)
    plt.ylabel(v, size=12)
    plt.grid(axis='y')
    
    plt.xticks(rotation=45, ha='right', va='top', rotation_mode='anchor', size=10)
    
    dmin = scores[v].min()
    dmax = scores[v].max()
    
    if dmin >= 0.0 and dmin <= 1.0 and dmax >= 0.0 and dmax <= 1.0:
        for vmin in [5000, 0.0]:
            if dmin > vmin:
                break
        for vmax in [0.5, 1.0]:
            if dmax < vmax:
                break
        plt.ylim(vmin, vmax)
        
    if v in lower_is_better:
        plt.gca().invert_yaxis()
    if v == 'calinski_harabasz':
        plt.ticklabel_format(axis='y', style='sci', scilimits=(0,0))
    plt.yticks(size=10)
    ax.yaxis.get_offset_text().set_fontsize(10)
plt.tight_layout(pad=0.8)

# %%
data = sc.read_mtx("../data/GSE118614/matrix.mtx")
data.obs = pd.read_table("../data/GSE118614/barcodes.tsv", index_col=0)
data.var = pd.read_table("../data/GSE118614/genes.tsv", index_col=0)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 110359 × 0
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'age', 'sample', 'celltype', 'short_celltype', 'RNA_snn_res.0.5', 'seurat_clusters'
#     obsm: 'X_pca', 'X_seurat', 'X_seurat_rpca', 'X_harmony', 'X_limma', 'X_bcd'

# %%
metadata.index = metadata.index.str.replace('-', '.')

# %%
adata = data[metadata.index, :]
adata.obs = metadata
for m in tqdm(methods):
    matrix_name = m
    adata.obsm[matrix_name] = embs[m].to_numpy()
# Out:
# C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\anndata\_core\anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<?, ?it/s]

# %%
from scib_metrics.benchmark import BioConservation, BatchCorrection
bm = Benchmarker(
    adata,
    batch_key=batch,
    label_key=label,
    embedding_obsm_keys=['pca', 'seurat', 'seurat_rpca', 'harmony', 'limma', 'bcd'],
    bio_conservation_metrics=BioConservation(isolated_labels=True, nmi_ari_cluster_labels_leiden=False, nmi_ari_cluster_labels_kmeans=False, silhouette_label=True, clisi_knn=False),
    batch_correction_metrics=BatchCorrection(silhouette_batch=True, ilisi_knn=False, kbet_per_label=False, graph_connectivity=True, pcr_comparison=False),
    n_jobs=6,
)
bm.benchmark()
# Out:
# Computing neighbors: 100%|███████████████████████████████████████████████████████████████| 6/6 [07:03<00:00, 70.53s/it]
# Embeddings:   0%|                                                                                | 0/6 [00:00<?, ?it/s]
# Metrics:   0%|                                                                                  | 0/10 [00:00<?, ?it/s]
# Metrics:   0%|                                               | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|███▉                                   | 1/10 [00:40<06:05, 40.62s/it, Bio conservation: isolated_labels]
# Metrics:  10%|███▊                                  | 1/10 [00:40<06:05, 40.62s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:21<05:25, 40.68s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:21<05:25, 40.68s/it, Batch correction: silhouette_batch]
# Metrics:  30%|███████████▍                          | 3/10 [01:26<02:51, 24.49s/it, Batch correction: silhouette_batch]
# Metrics:  30%|██████████▊                         | 3/10 [01:26<02:51, 24.49s/it, Batch correction: graph_connectivity]C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scib_metrics\_graph_connectivity.py:27: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  17%|████████████                                                            | 1/6 [01:26<07:13, 86.71s/it]
# Metrics:   0%|                                                                                  | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|                                               | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|███▉                                   | 1/10 [00:43<06:30, 43.38s/it, Bio conservation: isolated_labels]
# Metrics:  10%|███▊                                  | 1/10 [00:43<06:30, 43.38s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:27<05:52, 44.03s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:27<05:52, 44.03s/it, Batch correction: silhouette_batch]
# Metrics:  30%|███████████▍                          | 3/10 [01:33<03:04, 26.29s/it, Batch correction: silhouette_batch]
# Metrics:  30%|██████████▊                         | 3/10 [01:33<03:04, 26.29s/it, Batch correction: graph_connectivity]C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scib_metrics\_graph_connectivity.py:27: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  33%|████████████████████████                                                | 2/6 [02:59<06:02, 90.53s/it]
# Metrics:   0%|                                                                                  | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|                                               | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|███▉                                   | 1/10 [00:45<06:45, 45.01s/it, Bio conservation: isolated_labels]
# Metrics:  10%|███▊                                  | 1/10 [00:45<06:45, 45.01s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:29<05:58, 44.80s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:29<05:58, 44.80s/it, Batch correction: silhouette_batch]
# Metrics:  30%|███████████▍                          | 3/10 [01:34<03:07, 26.72s/it, Batch correction: silhouette_batch]
# Metrics:  30%|██████████▊                         | 3/10 [01:34<03:07, 26.72s/it, Batch correction: graph_connectivity]C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scib_metrics\_graph_connectivity.py:27: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  50%|████████████████████████████████████                                    | 3/6 [04:34<04:37, 92.58s/it]
# Metrics:   0%|                                                                                  | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|                                               | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|███▉                                   | 1/10 [00:44<06:40, 44.45s/it, Bio conservation: isolated_labels]
# Metrics:  10%|███▊                                  | 1/10 [00:44<06:40, 44.45s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:28<05:54, 44.34s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:28<05:54, 44.34s/it, Batch correction: silhouette_batch]
# Metrics:  30%|███████████▍                          | 3/10 [01:33<03:05, 26.49s/it, Batch correction: silhouette_batch]
# Metrics:  30%|██████████▊                         | 3/10 [01:33<03:05, 26.49s/it, Batch correction: graph_connectivity]C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scib_metrics\_graph_connectivity.py:27: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  67%|████████████████████████████████████████████████                        | 4/6 [06:09<03:06, 93.18s/it]
# Metrics:   0%|                                                                                  | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|                                               | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|███▉                                   | 1/10 [00:44<06:37, 44.12s/it, Bio conservation: isolated_labels]
# Metrics:  10%|███▊                                  | 1/10 [00:44<06:37, 44.12s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:28<05:52, 44.07s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:28<05:52, 44.07s/it, Batch correction: silhouette_batch]
# Metrics:  30%|███████████▍                          | 3/10 [01:33<03:04, 26.38s/it, Batch correction: silhouette_batch]
# Metrics:  30%|██████████▊                         | 3/10 [01:33<03:04, 26.38s/it, Batch correction: graph_connectivity]C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scib_metrics\_graph_connectivity.py:27: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings:  83%|████████████████████████████████████████████████████████████            | 5/6 [07:42<01:33, 93.34s/it]
# Metrics:   0%|                                                                                  | 0/10 [00:00<?, ?it/s]
#
# Metrics:   0%|                                               | 0/10 [00:00<?, ?it/s, Bio conservation: isolated_labels]
# Metrics:  10%|███▉                                   | 1/10 [00:44<06:43, 44.78s/it, Bio conservation: isolated_labels]
# Metrics:  10%|███▊                                  | 1/10 [00:44<06:43, 44.78s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:30<06:02, 45.34s/it, Bio conservation: silhouette_label]
# Metrics:  20%|███████▌                              | 2/10 [01:30<06:02, 45.34s/it, Batch correction: silhouette_batch]
# Metrics:  30%|███████████▍                          | 3/10 [01:36<03:10, 27.17s/it, Batch correction: silhouette_batch]
# Metrics:  30%|██████████▊                         | 3/10 [01:36<03:10, 27.17s/it, Batch correction: graph_connectivity]C:\Users\lshh\miniconda3\envs\py39_integration\lib\site-packages\scib_metrics\_graph_connectivity.py:27: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   tab = pd.value_counts(comps)
#
# Embeddings: 100%|████████████████████████████████████████████████████████████████████████| 6/6 [09:18<00:00, 93.15s/it]

# %%
bm.plot_results_table(min_max_scale=False)
